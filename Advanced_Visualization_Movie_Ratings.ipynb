# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv(r"C:\Users\91976\Downloads\Movie-Rating.csv")

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movie)
# Out:
# 559

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film','Genre','CriticRating','AudienceRatings','BudgetMilloin','Year']

# %%
movie.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMilloin  Year
# 0              8  2009

# %%
movie.Genre = movie.Genre.astype("category")

# %%
movie.Film = movie.Film.astype("category")
movie.Year = movie.Year.astype("category")

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMilloin
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMilloin    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
j = sns.jointplot( data = movie, x= "CriticRating", y="AudienceRatings", kind = 'reg')

# %%
j = sns.jointplot( data = movie, x= "CriticRating", y="AudienceRatings")

# %%
j = sns.jointplot( data = movie, x = 'CriticRating', y = 'AudienceRatings', kind='hex')

# %%
m1 = sns.distplot(movie.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movie.AudienceRatings, bins = 15)

# %%
#sns.set_style('darkgrid')
n1 = plt.hist(movie.AudienceRatings, bins=15)

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(movie.AudienceRatings, bins=20)

# %%
n1 = plt.hist(movie.CriticRating, bins=20) #uniform distribution

# %%
#h1 = plt.hist(movies.BudgetMillions)

plt.hist(movie.BudgetMilloin)
plt.show()

# %%
movie.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMilloin  Year
# 0              8  2009

# %%
plt.hist(movie[movie.Genre == 'Drama'].BudgetMilloin)
plt.show()

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movie[movie.Genre == 'Action'].BudgetMilloin, bins = 20)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMilloin, bins = 20)
plt.hist(movie[movie.Genre == 'Drama'].BudgetMilloin, bins = 20)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.hist([movie[movie.Genre == 'Action'].BudgetMilloin,\
          movie[movie.Genre == 'Drama'].BudgetMilloin, \
          movie[movie.Genre == 'Thriller'].BudgetMilloin, \
          movie[movie.Genre == 'Comedy'].BudgetMilloin],
         bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False)

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False, hue = 'Genre')

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False, hue = 'Genre', size = 10,aspect=1)

# %%
k1 = sns.kdeplot(movie.CriticRating,movie.AudienceRatings)

# %%
k1 = sns.kdeplot(movie.CriticRating,movie.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movie.BudgetMilloin,movie.AudienceRatings,shade_lowest=False,cmap='Greens_r')

# %%
k2 = sns.kdeplot(movie.BudgetMilloin,movie.CriticRating)

# %%
#subplots

f, ax = plt.subplots(1,2, figsize =(12,6))
#f, ax = plt.subplots(3,3, figsize =(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(movie.BudgetMilloin,movie.AudienceRatings,ax=axes[0])
k2 = sns.kdeplot(movie.BudgetMilloin,movie.CriticRating,ax = axes[1])

# %%
axes
# Out:
# array([<AxesSubplot:xlabel='BudgetMilloin', ylabel='AudienceRatings'>,
#        <AxesSubplot:xlabel='BudgetMilloin', ylabel='CriticRating'>],
#       dtype=object)

# %%
#Box plots - 

w = sns.boxplot(data=movie, x='Genre', y = 'CriticRating')

# %%
#violin plot

z = sns.violinplot(data=movie, x='Genre', y = 'CriticRating')

# %%
# Createing a Facet grid
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.scatter(movie.CriticRating,movie.AudienceRatings)

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings' ) #scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMilloin') #scatterplots are mapped in facetgrid

# %%
#
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movie.BudgetMilloin,movie.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(movie.BudgetMilloin,movie.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movie.CriticRating,movie.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movie.CriticRating, movie.AudienceRatings,cmap='Reds',ax = axes[1,1])

plt.show()

# %% [raw]
# Final discussion what we learn so far -
# 1> category datatype in python
# 2> jointplots
# 3> histogram
# 4> stacked histograms
# 5> Kde plot
# 6> subplot
# 7> violin plots
# 8> Factet grid
# 9> Building dashboards
